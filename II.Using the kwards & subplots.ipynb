# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import math
import numpy as np
t = np.arange(0, 2.5, 0.1)
y1 = list(map(math.sin, math.pi*t))
y2 = list(map(math.sin, math.pi*t+math.pi/2))
y3 = list(map(math.sin, math.pi*t-math.pi/2))
plt.plot(t,y1,t,y2,t,y3)
plt.plot(t,y1,'b--',t,y2,'g',t,y3,'r-')
# Out:
# Text(0, 0.5, 'Thickness of the blue line')

# %% [markdown]
# # Using the kwargs:
# The objects that make up a chart have many arrtibutes that characterize them. These attributes are all default values, but can be set through the use of __keyword args__, often refered as __keywargs__.
# These keywords are passed as arguments to functions called. In reference documentation of the various functions of the matplotlib library, you will always find them refered to as __kwargs__ inthe last position.
# For example, the plot() function that you are using in our examples is referred to in the following way.
# matplotlib.pyplot.plot(*args, **kwargs)
#
# For practical example, the thickness of a line can be changed if you set the __linewidth__ keyword.

# %%
plt.plot([1,2,4,2,1,0,1,2,1,4],linewidth=2.5)
plt.xlabel(' Notice Thickness of the blue line')
# Out:
# Text(0.5, 0, ' Notice Thickness of the blue line')

# %% [markdown]
# # Working with Multiple Figures and Axes:
# So far you have seen how all pyplot commands are routed to the display of a single figure. Actually, matplotlib allows management of multiple figures simultaneously, and within each figure, it offers the ability to view different plots defined as subplots.
# So when you are working with pyplot, you must always keep in mind the concept of current figure and current Axis (that is the plot shown within the figure).
#
# Now you will see an example where two subplots are represented in a single figure.
# The __subplot()__ function, in addition to subdividing the figure in different drawing areas, is used at the same time in order to focus the commands on a pecific subplot.
# The argument passed to the __subplot()__ function sets the mode of subdivision and which is the current subplot. The current subplot will be the only figure which will be affected by the commands. The argument of the subplot() function is composed of three integers.
# The first number defines how many parts of the figure is split into vertically.
# The second number defines how many parts the figure is divided into horizonally.
# The third issue selects which is the current subplot on which you can direct commands.

# %% [markdown]
# Now you will display two sinsodial trends (sin and cosine) and the best way to do that is to divide the canvas vertically in two horizontal subplots.
# So the numbers to pass as an argument are '211' and '212'.

# %%
 t = np.arange(0,5,0.1)
 y1 = np.sin(2*np.pi*t)
 y2 = np.sin(2*np.pi*t)
 plt.subplot(211) 
 plt.plot(t,y1,'b-.')
 plt.subplot(212)
 plt.plot(t,y2,'r--')
plt.xlabel("""The figure has been divided into two horizontal
             subplots""")
# Out:
# Text(0.5, 0, 'The figure has been divided into two horizontal\n            subplots')

# %% [markdown]
# Now  you do the same thing by dividing the figure in two vertical subplots. The number to be passed as arguments to the __subplot()__ function are '121' and '122'

# %%
t = np.arange(0.,1.,0.05)
y1 = np.sin(2*np.pi*t)
y2 = np.cos(2*np.pi*t)
plt.subplot(121)
plt.xlabel("""The figure has been divided into two horizontal
             subplots""")
plt.plot(t,y1,'b-.')
plt.subplot(122)
plt.plot(t,y2,'r--')
